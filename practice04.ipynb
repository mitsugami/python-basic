# %% [markdown]
# <a href="https://colab.research.google.com/github/mitsugami/python-basic/blob/main/practice04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# （上の「Open in Colab」をクリックすると，このノートブックがGoogle Colaboratory上で開かれ，自由に編集・実行できます）

# %% [markdown]
# # Python基礎（第4回）演習用Notebook

# %% [markdown]
# ---
# ## strオブジェクト，メソッド，スライス

# %% [markdown]
# ### メソッドとは

# %% [markdown]
# 型（正確にはクラス）に対して定義された機能（関数のようなもの）をメソッドといいます．メソッドを呼び出すには **オブジェクト名.メソッド名()** と書きます．

# %%
'Hello, Python'.count('o')

# %% [markdown]
# 文字列が代入された変数に対しても機能します．

# %%
a = 'Hello, Python'
a.count('o')

# %% [markdown]
# ### strクラスのメソッド

# %% [markdown]
# strクラスのメソッドにはさまざまなものがあります．

# %%
a = 'PYTHON'
a.lower()

# %%
a = 'python'
a.upper()

# %%
a = '2022-09-30'
a.split('-')

# %%
a = 'Java言語'
a.replace('Java', 'Python')

# %% [markdown]
# ### strクラスのformatメソッド

# %%
year = 2022
month = 9
day = 30
message = '今日は{}年{}月{}日です'.format(year, month, day)
print(message)

# %%
year = 2022
month = 9
day = 30
message = '今日は{1}月{2}日です．西暦{0}年です．'.format(year, month, day)
print(message)

# %% [markdown]
# ### in演算子
#
# 文字列1が文字列2に含まれるかの判定に用いられる．含まれていれば True ，そうでなければ False となる．

# %%
'cat' in 'catch'

# %%
'Z' in 'ABCDE'

# %% [markdown]
# もちろん，文字列が代入された変数に対しても動作します．

# %%
s1 = 'py'
s2 = 'python'
s1 in s2

# %% [markdown]
# ### スライス
#
# 文字列（str型）中の1文字ではなくある範囲の文字列を取り出したいときには，スライスを使います．

# %%
a = 'Python'
print(a[4])   # インデックスによる1文字へのアクセス
print(a[1:3]) # スライスによる範囲指定

# %% [markdown]
# スライスの，start/end の値は省略することができ，省略された場合はそれぞれ先頭と末尾を意味します．

# %%
a = 'Python'
print(a[:3])
print(a[3:])
print(a[:])

# %% [markdown]
# [start:end:step] と3つ目の値を指定すると，3つ目の値は増分を意味します．

# %%
a = 'abcdefghijklmn'
print( a[0:6:2] )
print( a[0:9:3] )
print( a[::2] )

# %% [markdown]
# ---
# ## リスト

# %% [markdown]
# ### リストのさまざまなメソッド

# %%
a = [10, 20, 30, 40]
a.append(50)
print(a)

# %%
a = [10, 20, 30, 40]
a.insert(2, 50)
print(a)

# %%
a = [10, 20, 30, 40]
a.remove(30)
print(a)

# %%
a = [10, 20, 30, 40]
b = a.pop()
print(b)
print(a)

# %%
a = [10, 20, 30, 40]
a.clear()
print(a)

# %%
a = [10, 20, 30, 40]
b = a.index(30)
print(b)

# %%
a = [10, 20, 30, 40, 20, 20]
b = a.count(20)
print(b)

# %%
a = [10, 20, 30, 40]
a.reverse()
print(a)

# %% [markdown]
# ### メソッド以外のリスト操作

# %%
a = [10, 20, 30, 40]
del a[2]
print(a)

# %%
a = [10, 30, 40]
b = [0, 1]
c = a + b
print(c)

# %%
a = [10, 20, 30, 40]
print( 10 in a )
print( 50 in a )

# %%
a = [10, 20, 30, 40]
len(a)

# %%
a = [10, 20, 30, 40, 0]
sorted(a)

# %%
a = [10, 20, 30, 40, 0]
sorted(a, reverse=True)

# %% [markdown]
# ### 内包表記
#
# リストの要素として，各要素が数列の一般項のようにある変数で書けるものの場合，内包表記を使うと簡潔に記述することができます．

# %%
data = [2**n for n in range(1, 11)]
data

# %%
[str(n)+'月' for n in range(1, 13)]

# %% [markdown]
# ### リストを含むリスト
#
# リストは任意の型を要素にでき，混在もできます．リストの要素がリストであっても構いません．

# %%
data = [ [1, 2], [3, 4, 5] ]
print( data[0][0] )
print( data[0][1] )
print( data[1][0] )
print( data[1][1] )
print( data[1][2] )

# %% [markdown]
# ### リストのスライス
#
# strと同様，リストもスライスを利用できます．

# %%
a = [1, 4, 9, 16, 25, 36, 49, 64, 81]
print( a[1:3] )
print( a[4:] )
print( a[0:5:2] )

# %% [markdown]
# ---
# ## タプル

# %% [markdown]
# タプルもリスト同様，複数の要素を格納するためのものです．インデックスで要素にアクセスできるのも同じです．

# %%
a = [1, 2, 3, 4]   # これはリスト
print(a)
print(a[0])

# %%
a = (1, 2, 3, 4)   # これはタプル
print(a)
print(a[0])

# %% [markdown]
# しかし，タプルでは，要素の値の変更ができません．

# %%
a = [1, 2, 3, 4]   # これはリストなので書き換えOK
a[0] = 99
print(a)

# %%
a = (1, 2, 3, 4)   # これはタプルなので書き換え不可．エラーとなる．
a[0] = 99
print(a)

# %% [markdown]
# ### ()の省略とアンパック代入

# %% [markdown]
# タプル作成時に () を省略できます．

# %%
a = 1, 2, 3, 4
print(a)

# %% [markdown]
# 以下のように，複数の変数にタプルを代入するような代入文を書くと，順に1つずつ値を代入できます．

# %%
a, b, c = (1, 2, 3)
print(a)
print(b)
print(c)

# %% [markdown]
# 以上の2つの性質から，以下のような代入が可能です．

# %%
x, y, z = 1, 2, 3
print(x)
print(y)
print(z)

# %% [markdown]
# ---
# ## 辞書

# %% [markdown]
# リスト・タプルは要素の特定にインデックスという整数値を使いますが，その代わりに任意の値をキーとして用いるのが辞書です．

# %%
info = {'firstname':'太郎', 'lastname':'山田', 'address':'茨城県つくば市'}
info['firstname']

# %% [markdown]
# keysメソッドをを使うとすべてのキーだけを抽出できる

# %%
info = {'firstname':'太郎', 'lastname':'山田', 'address':'茨城県つくば市'}
for k in info.keys():
  print(k)

# %% [markdown]
# valuesメソッドを使うとすべての値だけを抽出できる

# %%
info = {'firstname':'太郎', 'lastname':'山田', 'address':'茨城県つくば市'}
for v in info.values():
  print(v)

# %% [markdown]
# すべてのキーと値のペアを取り出したい場合はitemsメソッドを使う

# %%
info = {'firstname':'太郎', 'lastname':'山田', 'address':'茨城県つくば市'}
for i in info.items():
  print(i)

# %% [markdown]
# ### その他の辞書操作

# %%
info = {'firstname':'太郎', 'lastname':'山田', 'address':'茨城県つくば市'}

# %%
info.get('firstname')

# %%
info.get('tel')

# %%
info['tel'] = '090-000-0000'
info.get('tel')

# %%
del info['tel']

# %%
len(info)

# %%
'firstname' in info

# %%
'age' in info

# %% [markdown]
# ---
# ## 集合（セット）

# %% [markdown]
# 集合（セット）も複数の値を格納するものだが，要素の重複が認められない．
#
# また，要素の順序という概念がなく，生成時と参照時で表示順が異なる．（順序の概念が無いので，それをソートするなどはできない）

# %%
a = {'A', 'B', 'C', 'D'}
print(a)

# %% [markdown]
# 生成時に重複した要素を書いていても，格納されるのは各要素1つずつだけとなる．

# %%
a = {'A', 'B', 'B', 'C', 'C', 'C'}
print(a)

# %% [markdown]
# ### issubsetメソッドによる包含関係の判定

# %%
set1 = {'A', 'B', 'C'}
set2 = {'B', 'C'}

print( set1.issubset(set2) )
print( set2.issubset(set1) )

# %% [markdown]
# ### 集合同士の演算
#
# 以下，集合同士の演算の例です．
#
# 1つ目のセルはデータの代入のみ行うので何も表示されません．2つ目以降は，その代入された集合に対して各種演算を行いその結果を表示するものです．

# %%
set1 = {'A', 'B', 'C'}
set2 = {'A', 'B', 'D'}

# %%
print( set1 | set2 )

# %%
print( set1 & set2)

# %%
print( set1 - set2)

# %%
print( set1 ^ set2)

# %% [markdown]
# ---
# ## リストと集合の相互変換

# %% [markdown]
# リスト（・タプル）と集合は相互に変換可能です．
#
# 下の例では，data はリスト，それを集合に変換したのが a ，さらにそれをリストに戻したのが b となります．

# %%
data = [1, 2, 3]

# %%
a = set(data)
print(a)

# %%
b = list(a)
print(b)

# %% [markdown]
# リストと集合の相互変換は，リストの中の要素の重複を解消したい場合などに利用されます．
#
# 以下は，30以下の自然数で，3または5の倍数を列挙したリストを作成する例です．

# %%
a = [3*n for n in range(1,11)]
b = [5*n for n in range(1, 7)]

c = a + b
d = set(c)
e = list(d)
print(e)

# %% [markdown]
# 別の方法もあります．

# %%
a = [3*n for n in range(1,11)]
b = [5*n for n in range(1, 7)]

c = set(a)
d = set(b)
e = list( c | d )
print(e)
